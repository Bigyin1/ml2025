# %%
import numpy as np
import pandas as pd

import lightgbm as lgb

from sklearn.svm import SVC
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.ensemble import BaggingClassifier


from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report, accuracy_score

from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import loguniform, randint

# %%
train = pd.read_csv("train_processed.csv")
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13453 entries, 0 to 13452
# Data columns (total 39 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          13453 non-null  int64
#  1   feature_01  13453 non-null  float64
#  2   feature_02  11481 non-null  float64
#  3   feature_03  13453 non-null  int64
#  4   feature_04  11433 non-null  float64
#  5   feature_05  13453 non-null  int64
#  6   feature_06  11403 non-null  float64
#  7   feature_07  13453 non-null  int64
#  8   feature_08  13453 non-null  int64
#  9   feature_09  13453 non-null  float64
#  10  feature_10  13453 non-null  float64
#  11  feature_11  13453 non-null  int64
#  12  feature_12  13453 non-null  int64
#  13  feature_13  13453 non-null  int64
#  14  feature_14  11414 non-null  float64
#  15  feature_15  13453 non-null  float64
#  16  feature_16  13453 non-null  float64
#  17  feature_17  13453 non-null  float64
#  18  feature_18  13453 non-null  float64
#  19  feature_19  13453 non-null  float64
#  20  feature_20  13453 non-null  float64
#  21  feature_21  13453 non-null  float64
#  22  feature_22  13453 non-null  float64
#  23  feature_23  13453 non-null  float64
#  24  feature_24  13453 non-null  float64
#  25  feature_25  13453 non-null  float64
#  26  feature_26  13453 non-null  float64
#  27  feature_27  13453 non-null  float64
#  28  feature_28  13453 non-null  float64
#  29  feature_29  13453 non-null  float64
#  30  feature_30  13453 non-null  float64
#  31  feature_31  13453 non-null  float64
#  32  feature_32  11403 non-null  float64
#  33  feature_33  11403 non-null  float64
#  34  feature_34  13453 non-null  object
#  35  feature_35  13453 non-null  object
#  36  feature_36  13453 non-null  object
#  37  feature_37  13453 non-null  object
#  38  target      13453 non-null  int64
# dtypes: float64(26), int64(9), object(4)
# memory usage: 4.0+ MB

# %%
train
# Out:
#           id   feature_01  feature_02  feature_03  feature_04  feature_05  \
# 0       6739    63.649596       156.0      966898    966930.0         386
# 1      13633  1077.950732      1122.0     2401744   2401760.0         106
# 2      17450   775.697727       756.0      152117    152274.0         144
# 3      19017  1249.671295         NaN     1154994   1155025.0         168
# 4      12119  1297.659733      1296.0      467888    467902.0          97
# ...      ...          ...         ...         ...         ...         ...
# 13448   1293   809.689074       796.0     1388292   1388304.0          34
# 13449   5148    43.010153       216.0     2087881   2087946.0        6515
# 13450   4528   749.519408       740.0     2195695   2195707.0          80
# 13451   5817  1146.829348      1187.0        9228      9246.0         770
# 13452  10817   507.993250       494.0     1248676   1248687.0         111
#
#        feature_06  feature_07  feature_08  feature_09  ...  feature_29  \
# 0             NaN          22       39202   86.700831  ...  117.994612
# 1           0.015          11        -999  103.129709  ...  123.397491
# 2           0.024          12       15517   94.270979  ...  115.789506
# 3           0.016          20        -999   91.376335  ...  122.521749
# 4           0.008          14        9693   79.828246  ...  103.576787
# ...           ...         ...         ...         ...  ...         ...
# 13448       0.007           4        4409  103.023377  ...  121.222489
# 13449       0.257         123      684236   44.059624  ...  120.892421
# 13450         NaN          17        9155  100.935469  ...  121.705560
# 13451       0.059          87       79690   85.636994  ...  132.534438
# 13452       0.009          13       11682   86.850580  ...  116.286079
#
#        feature_30  feature_31  feature_32  feature_33  feature_34  feature_35  \
# 0        0.668238    0.815287         NaN         NaN   Very_High      Medium
# 1        0.868849    0.987009    0.023715   -0.046797   Very_High      Medium
# 2        0.579598    0.588482    0.031276    0.062870        High      Medium
# 3        0.508570    0.402647    0.017443    0.079964   Very_High      Medium
# 4        0.882215    0.849826    0.028379    0.003948   Very_High      Medium
# ...           ...         ...         ...         ...         ...         ...
# 13448    1.016905    0.928651    0.011469   -0.028761   Very_High      Medium
# 13449    0.621096    0.517800    0.251611    0.186348      Medium         Low
# 13450    0.664470    0.603057         NaN         NaN        High      Medium
# 13451    0.186090    0.048947    0.062652    0.029598   Very_High      Medium
# 13452    0.886765    0.893148    0.011084   -0.069440   Very_High      Medium
#
#        feature_36      feature_37  target
# 0         Cat_039         unknown       0
# 1         Cat_033          Type_A       0
# 2         Cat_000          Type_D       0
# 3         Cat_017          Type_A       0
# 4         Cat_019         Type A+       0
# ...           ...             ...     ...
# 13448     Cat_043         unknown       1
# 13449     Cat_048  type_b_special       1
# 13450     Cat_028         Type A+       0
# 13451     Cat_017  type_b_special       0
# 13452     Cat_017  type_b_special       0
#
# [13453 rows x 39 columns]

# %%
train = train.replace("unknown", np.nan)

# %%
def create_auto_preprocessor(X: pd.DataFrame):
    """
    Автоматически создает препроцессор с обработкой NaN
    """

    # Автоматически определяем типы колонок
    numeric_features = X.select_dtypes(include=[np.number]).columns.tolist()
    categorical_features = X.select_dtypes(
        include=["object", "category"]
    ).columns.tolist()

    print(f"Числовые колонки: {numeric_features}")
    print(f"Категориальные колонки: {categorical_features}")

    # Проверяем наличие NaN
    numeric_with_nan = [
        col for col in numeric_features if X[col].isnull().any()
    ]
    categorical_with_nan = [
        col for col in categorical_features if X[col].isnull().any()
    ]

    print(f"Числовые колонки с NaN: {numeric_with_nan}")
    print(f"Категориальные колонки с NaN: {categorical_with_nan}")

    # Создаем трансформеры
    transformers = []

    transformers.append(
        (
            "num",
            Pipeline(
                [
                    ("imputer", SimpleImputer(strategy="median")),
                    ("scaler", StandardScaler()),
                ]
            ),
            numeric_features,
        )
    )

    transformers.append(
        (
            "cat",
            Pipeline(
                [
                    ("imputer", SimpleImputer(strategy="most_frequent")),
                    (
                        "encoder",
                        OneHotEncoder(handle_unknown="ignore"),
                    ),
                ]
            ),
            categorical_features,
        )
    )

    preprocessor = ColumnTransformer(transformers=transformers)
    return preprocessor

# %%
X = train.drop("target", axis=1)
Y = train["target"]

X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, train_size=0.8, test_size=0.2, random_state=42
)

# %%
preprocessor = create_auto_preprocessor(X)
# Out:
# Числовые колонки: ['id', 'feature_01', 'feature_02', 'feature_03', 'feature_04', 'feature_05', 'feature_06', 'feature_07', 'feature_08', 'feature_09', 'feature_10', 'feature_11', 'feature_12', 'feature_13', 'feature_14', 'feature_15', 'feature_16', 'feature_17', 'feature_18', 'feature_19', 'feature_20', 'feature_21', 'feature_22', 'feature_23', 'feature_24', 'feature_25', 'feature_26', 'feature_27', 'feature_28', 'feature_29', 'feature_30', 'feature_31', 'feature_32', 'feature_33']
# Категориальные колонки: ['feature_34', 'feature_35', 'feature_36', 'feature_37']
# Числовые колонки с NaN: ['feature_02', 'feature_04', 'feature_06', 'feature_14', 'feature_32', 'feature_33']
# Категориальные колонки с NaN: ['feature_37']

# %%
import lightgbm as lgb
from sklearn.ensemble import BaggingClassifier

bagging_lgb = BaggingClassifier(
    estimator=lgb.LGBMClassifier(
        n_estimators=50,
        learning_rate=0.1,
        max_depth=6,
        reg_alpha=0.1,
        reg_lambda=3,
        random_state=42,
    ),
    n_estimators=10,  # 10 моделей в ансамбле
    max_samples=0.8,  # 80% данных для каждой модели
    max_features=0.8,  # 80% признаков для каждой модели
    bootstrap=True,  # Выборка с возвращением
    bootstrap_features=False,  # Без возвращения для признаков
    random_state=42,
    n_jobs=-1,  # Использовать все ядра
)


ml_pipeline = Pipeline(
    [
        ("preprocessor", preprocessor),
        ("classifier", bagging_lgb),
    ]
)

# %%
ml_pipeline.fit(X_train, Y_train)

# Оценка модели
train_score = ml_pipeline.score(X_train, Y_train)
test_score = ml_pipeline.score(X_test, Y_test)

print(f"Точность на тренировочных данных: {train_score:.3f}")
print(f"Точность на тестовых данных: {test_score:.3f}")
# Out:
# [LightGBM] [Info] Number of positive: 3959, number of negative: 6803
# [LightGBM] [Info] Number of positive: 3959, number of negative: 6803
# [LightGBM] [Info] Number of positive: 3959, number of negative: 6803
# [LightGBM] [Info] Number of positive: 3959, number of negative: 6803
# [LightGBM] [Info] Number of positive: 3959, number of negative: 6803
# [LightGBM] [Info] Number of positive: 3959, number of negative: 6803
# [LightGBM] [Info] Number of positive: 3959, number of negative: 6803
# [LightGBM] [Info] Number of positive: 3959, number of negative: 6803
# [LightGBM] [Info] Number of positive: 3959, number of negative: 6803
# [LightGBM] [Info] Number of positive: 3959, number of negative: 6803
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.091270 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6339
# [LightGBM] [Info] Number of data points in the train set: 10762, number of used features: 80
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.135872 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6446
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.104535 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6099
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.368916 -> initscore=-0.536869
# [LightGBM] [Info] Number of data points in the train set: 10762, number of used features: 80
# [LightGBM] [Info] Start training from score -0.536869
# [LightGBM] [Info] Number of data points in the train set: 10762, number of used features: 80
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.151877 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6337
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.155941 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6359
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.367290 -> initscore=-0.543860
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.367290 -> initscore=-0.543860
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.175703 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.143958 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6773
# [LightGBM] [Info] Total Bins 6088
# [LightGBM] [Info] Number of data points in the train set: 10762, number of used features: 80
# [LightGBM] [Info] Start training from score -0.543860
# [LightGBM] [Info] Number of data points in the train set: 10762, number of used features: 80
# [LightGBM] [Info] Number of data points in the train set: 10762, number of used features: 80
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.154921 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6626
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.354513 -> initscore=-0.599261
# [LightGBM] [Info] Start training from score -0.543860
# [LightGBM] [Info] Number of data points in the train set: 10762, number of used features: 80
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.363341 -> initscore=-0.560894
# [LightGBM] [Info] Number of data points in the train set: 10762, number of used features: 80
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.364154 -> initscore=-0.557380
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.376583 -> initscore=-0.504079
# [LightGBM] [Info] Start training from score -0.599261
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.380532 -> initscore=-0.487291[LightGBM] [Info] Start training from score -0.560894
#
# [LightGBM] [Info] Start training from score -0.557380
# [LightGBM] [Info] Start training from score -0.504079
# [LightGBM] [Info] Start training from score -0.487291
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.293878 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6339
# [LightGBM] [Info] Number of data points in the train set: 10762, number of used features: 80
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.376931 -> initscore=-0.502595
# [LightGBM] [Info] Start training from score -0.502595
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.384031 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6626
# [LightGBM] [Info] Number of data points in the train set: 10762, number of used features: 80
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.362295 -> initscore=-0.565416
# [LightGBM] [Info] Start training from score -0.565416
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# /home/ser/myProjects/mipt/ml/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ser/myProjects/mipt/ml/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ser/myProjects/mipt/ml/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ser/myProjects/mipt/ml/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ser/myProjects/mipt/ml/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ser/myProjects/mipt/ml/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ser/myProjects/mipt/ml/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ser/myProjects/mipt/ml/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ser/myProjects/mipt/ml/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ser/myProjects/mipt/ml/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# Точность на тренировочных данных: 0.838
# Точность на тестовых данных: 0.799
# /home/ser/myProjects/mipt/ml/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ser/myProjects/mipt/ml/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ser/myProjects/mipt/ml/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ser/myProjects/mipt/ml/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ser/myProjects/mipt/ml/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ser/myProjects/mipt/ml/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ser/myProjects/mipt/ml/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ser/myProjects/mipt/ml/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ser/myProjects/mipt/ml/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/ser/myProjects/mipt/ml/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(

# %%
test = pd.read_csv("test_processed.csv")

# %%
test_pred = ml_pipeline.predict(test)
# Out:
# /home/ser/myProjects/mipt/ml/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(

# %%
res_df = pd.DataFrame()

res_df["id"] = test["id"]
res_df["target"] = test_pred

res_df.to_csv("test_result.csv", index=False)
